# %% [markdown]
# # 4.6 Task

# %% [markdown]
# ## This script contains the following points:
# 1. (Step 3) Importing libraries, defining project path, and importing datasets
# 2. (Step 4) Check dimensions of imported dataframes
# 3. (Step 5) Merge df_ords_combined_prods_combined_checked and df_prods_checked
# 4. (Step 6) Confirming the merge with merge flag
# 5. (Step 7) Exporting dataframe

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/ronaldcameron/Documents/Data Analytics/Achievement 4 - Python/02:2023 Insta Cart Basket Analysis/Project Management'

# %%
df_ords_products_combined = pd.read_pickle(os.path.join(path, 'orders_products_combines.pkl'))

# %%
df_ords_products_combined.shape
# Out:
# (30356421, 10)

# %%
df_prods = pd.read_csv(r'/Users/ronaldcameron/Documents/Data Analytics/Achievement 4 - Python/02:2023 Insta Cart Basket Analysis/Project Management/products_checked.csv')

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_ords_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2398795        1             2                   3                  7
# 1   2398795        1             2                   3                  7
# 2   2398795        1             2                   3                  7
# 3   2398795        1             2                   3                  7
# 4   2398795        1             2                   3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                    15.0         196                  1          1   both
# 1                    15.0       10258                  2          0   both
# 2                    15.0       12427                  3          1   both
# 3                    15.0       13176                  4          0   both
# 4                    15.0       26088                  5          1   both

# %%
#Drop column 
df_prods.drop(columns = ['Unnamed: 0'])
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
#Combine data
orders_products_combined = df_prods.merge(df_ords_products_combined, on = 'product_id', indicator = 'exists')

# %%
#Export data to pkl
orders_products_combined.to_pickle(os.path.join(path, 'orders_products_merged.pkl'))
